# %%
# Importing api requests
import requests
import json

# Importing Necessary Libraries for Predictive Modeling
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
from sklearn.preprocessing import MinMaxScaler

# %%
# Set my API Key
api_key = "OX9K2D1Q89P22TMN"

# %%
# Set base url for API
baseUrl = "https://www.alphavantage.co/query"
# Core Stock API Functions
def timeSeriesIntraday(symbol, interval):
    # Set base url for API
    baseUrl = "https://www.alphavantage.co/query"
    
    # Make API Request
    response = requests.get("https://www.alphavantage.co/query", params={
        "function": "TIME_SERIES_INTRADAY",
        "symbol": symbol,
        "interval": interval,
        "apikey": "OX9K2D1Q89P22TMN"
    })
    
    # Print Response
    print(response.text)
    
def timeSeriesIntradayExtendo(symbol, interval, yearMonth):
    # Set base url for API
    baseUrl = "https://www.alphavantage.co/query"
    
    # Make API Request
    response = requests.get("https://www.alphavantage.co/query", params={
        "function": "TIME_SERIES_INTRADAY_EXTENDED",
        "symbol": symbol,
        "interval": interval,
        "slice": yearMonth,
        "apikey": "OX9K2D1Q89P22TMN"
    })
    
    # Print Response
    print(response.text)

def timeSeriesDailyAdj(symbol):
    # Set base url for API
    baseUrl = "https://www.alphavantage.co/query"
    
    # Make API Request
    response = requests.get("https://www.alphavantage.co/query", params={
        "function": "TIME_SERIES_DAILY_ADJUSTED",
        "symbol": symbol,
        "apikey": "OX9K2D1Q89P22TMN"
    })
    
    # Print Response
    print(response.text)
    
def timeSeriesWeekly(symbol):
    # Set base url for API
    baseUrl = "https://www.alphavantage.co/query"
    
    # Make the API Request
    response = requests.get("https://www.alphavantage.co/query", params={
        "function": "TIME_SERIES_WEEKLY",
        "symbol": symbol,
        "apikey": "OX9K2D1Q89P22TMN"
    })

    # Print Response
    print(response.text)
    
def timeSeriesWeeklyAdj(symbol):
    # Set base url for API
    baseUrl = "https://www.alphavantage.co/query"
    
    # Make the API Request
    response = requests.get("https://www.alphavantage.co/query", params={
        "function": "TIME_SERIES_WEEKLY_ADJUSTED",
        "symbol": symbol,
        "datatype": "JSON",
        "apikey": "OX9K2D1Q89P22TMN"
    })

    # Print Response
    return(response.text)
    
def timeSeriesMonthly(symbol):
    # Set base url for API
    baseUrl = "https://www.alphavantage.co/query"
    
    # Make the API Request
    response = requests.get("https://www.alphavantage.co/query", params={
        "function": "TIME_SERIES_MONTHLY",
        "symbol": symbol,
        "apikey": "OX9K2D1Q89P22TMN"
    })

    # Print Response
    print(response.text)
    
def timeSeriesMonthlyAdj(symbol):
    # Set base url for API
    baseUrl = "https://www.alphavantage.co/query"
    
    # Make the API Request
    response = requests.get("https://www.alphavantage.co/query", params={
        "function": "TIME_SERIES_MONTHLY_ADJUSTED",
        "symbol": symbol,
        "apikey": "OX9K2D1Q89P22TMN"
    })

    # Print Response
    print(response.text)

# %%
# Testing functions
# timeSeriesIntraday("AAPL", "60min")
# timeSeriesIntradayExtendo("AAPL", "60min", "year1month1")
#timeSeriesDailyAdj("RIOT")
#timeSeriesWeekly("IBM")
# timeSeriesWeeklyAdj("COIN")
#timeSeriesMonthly("AMD")
#timeSeriesMonthlyAdj("CAT")

# %%
# Preparing Data
# Weekly Data Taken From Alpha Vantage API
# Problem: Predicting future price of a stock based on its historical data
jsonFile1 = timeSeriesWeeklyAdj("COIN")
jsonFile2 = timeSeriesWeeklyAdj("AAPL")
jsonFile3 = timeSeriesWeeklyAdj("AMD")
jsonFile4 = timeSeriesWeeklyAdj("AMZN")
jsonFile5 = timeSeriesWeeklyAdj("GOOGL")

print(jsonFile1)
# Out:
# {
#     "Meta Data": {
#         "1. Information": "Weekly Adjusted Prices and Volumes",
#         "2. Symbol": "COIN",
#         "3. Last Refreshed": "2022-12-16",
#         "4. Time Zone": "US/Eastern"
#     },
#     "Weekly Adjusted Time Series": {
#         "2022-12-16": {
#             "1. open": "39.9800",
#             "2. high": "46.3300",
#             "3. low": "34.7100",
#             "4. close": "36.6000",
#             "5. adjusted close": "36.6000",
#             "6. volume": "76477243",
#             "7. dividend amount": "0.0000"
#         },
#         "2022-12-09": {
#             "1. open": "47.9800",
#             "2. high": "49.8500",
#             "3. low": "40.1500",
#             "4. close": "40.2400",
#             "5. adjusted close": "40.2400",
#             "6. volume": "53601053",
#             "7. dividend amount": "0.0000"
#         },
#         "2022-12-02": {
#             "1. open": "43.3000",
#             "2. high": "47.7000",
# ...

# %%
#Creating a Pandas DF and Cleaning the Data

data1 = json.loads(jsonFile1)
data1 = data1['Weekly Adjusted Time Series']
index1 = []
columns1=[]
for key in data1:
    index1.append(key)
#print(index1)
values1 = list(data1.values())
#print(values)
innerDict1 = values1[0]
for key in innerDict1:
    columns1.append(key)
#print(columns1)
#print(data1)
df1 = pd.DataFrame(values1, columns=columns1, index=index1)
df1['1. open'] = df1['1. open'].astype(float)
df1['2. high'] = df1['2. high'].astype(float)
df1['3. low'] = df1['3. low'].astype(float)
df1['4. close'] = df1['4. close'].astype(float)
df1['5. adjusted close'] = df1['5. adjusted close'].astype(float)
df1['6. volume'] = df1['6. volume'].astype(float)
df1['7. dividend amount'] = df1['7. dividend amount'].astype(float)
df1.head()

# Creating a Pandas DF and Cleaning the Data

data2 = json.loads(jsonFile2)
data2 = data2['Weekly Adjusted Time Series']
index2 = []
columns2=[]
for key in data2:
    index2.append(key)
#print(index2)
values2 = list(data2.values())
#print(values2)
innerDict2 = values2[0]
for key in innerDict2:
    columns2.append(key)
#print(columns2)
#print(data2)
df2 = pd.DataFrame(values2, columns=columns2, index=index2)
df2['1. open'] = df2['1. open'].astype(float)
df2['2. high'] = df2['2. high'].astype(float)
df2['3. low'] = df2['3. low'].astype(float)
df2['4. close'] = df2['4. close'].astype(float)
df2['5. adjusted close'] = df2['5. adjusted close'].astype(float)
df2['6. volume'] = df2['6. volume'].astype(float)
df2['7. dividend amount'] = df2['7. dividend amount'].astype(float)
df2.head()

# Creating a Pandas DF and Cleaning the Data

data3 = json.loads(jsonFile3)
data3 = data3['Weekly Adjusted Time Series']
index3 = []
columns3=[]
for key in data3:
    index3.append(key)
#print(index3)
values3 = list(data3.values())
#print(values3)
innerDict3 = values3[0]
for key in innerDict3:
    columns3.append(key)
#print(columns3)
#print(data3)
df3 = pd.DataFrame(values3, columns=columns3, index=index3)
df3['1. open'] = df3['1. open'].astype(float)
df3['2. high'] = df3['2. high'].astype(float)
df3['3. low'] = df3['3. low'].astype(float)
df3['4. close'] = df3['4. close'].astype(float)
df3['5. adjusted close'] = df3['5. adjusted close'].astype(float)
df3['6. volume'] = df3['6. volume'].astype(float)
df3['7. dividend amount'] = df3['7. dividend amount'].astype(float)
df3.head()

# Creating a Pandas DF and Cleaning the Data

data4 = json.loads(jsonFile4)
data4 = data4['Weekly Adjusted Time Series']
index4 = []
columns4=[]
for key in data4:
    index4.append(key)
#print(index4)
values4 = list(data4.values())
#print(values4)
innerDict4 = values4[0]
for key in innerDict4:
    columns4.append(key)
#print(columns4)
#print(data4)
df4 = pd.DataFrame(values4, columns=columns4, index=index4)
df4['1. open'] = df4['1. open'].astype(float)
df4['2. high'] = df4['2. high'].astype(float)
df4['3. low'] = df4['3. low'].astype(float)
df4['4. close'] = df4['4. close'].astype(float)
df4['5. adjusted close'] = df4['5. adjusted close'].astype(float)
df4['6. volume'] = df4['6. volume'].astype(float)
df4['7. dividend amount'] = df4['7. dividend amount'].astype(float)
df4.head()

# Creating a Pandas DF and Cleaning the Data

data5 = json.loads(jsonFile5)
data5 = data5['Weekly Adjusted Time Series']
index5 = []
columns5=[]
for key in data5:
    index5.append(key)
#print(index5)
values5 = list(data5.values())
#print(values5)
innerDict5 = values5[0]
for key in innerDict5:
    columns5.append(key)
#print(columns5)
#print(data5)
df5 = pd.DataFrame(values3, columns=columns3, index=index3)
df5['1. open'] = df5['1. open'].astype(float)
df5['2. high'] = df5['2. high'].astype(float)
df5['3. low'] = df5['3. low'].astype(float)
df5['4. close'] = df5['4. close'].astype(float)
df5['5. adjusted close'] = df5['5. adjusted close'].astype(float)
df5['6. volume'] = df5['6. volume'].astype(float)
df5['7. dividend amount'] = df5['7. dividend amount'].astype(float)
df5.head()



frames = [df1, df2, df3, df4, df5]
df = pd.concat(frames)
df.head()
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close   6. volume  \
# 2022-12-16   39.980    46.33   34.71     36.60              36.60  76477243.0
# 2022-12-09   47.980    49.85   40.15     40.24              40.24  53601053.0
# 2022-12-02   43.300    47.70   41.51     47.67              47.67  57123348.0
# 2022-11-25   43.600    46.17   40.61     44.28              44.28  64282378.0
# 2022-11-18   55.695    58.00   44.31     45.26              45.26  93272794.0
#
#             7. dividend amount
# 2022-12-16                 0.0
# 2022-12-09                 0.0
# 2022-12-02                 0.0
# 2022-11-25                 0.0
# 2022-11-18                 0.0

# %%
# Perform feature engineering to create new features that may be useful for prediction

df['avg_price'] = (df['2. high'] + df['3. low']) / 2
df['price_range'] = df['2. high'] - df['3. low']
df.head()
# Out:
#             1. open  2. high  3. low  4. close  5. adjusted close   6. volume  \
# 2022-12-16   39.980    46.33   34.71     36.60              36.60  76477243.0
# 2022-12-09   47.980    49.85   40.15     40.24              40.24  53601053.0
# 2022-12-02   43.300    47.70   41.51     47.67              47.67  57123348.0
# 2022-11-25   43.600    46.17   40.61     44.28              44.28  64282378.0
# 2022-11-18   55.695    58.00   44.31     45.26              45.26  93272794.0
#
#             7. dividend amount  avg_price  price_range
# 2022-12-16                 0.0     40.520        11.62
# 2022-12-09                 0.0     45.000         9.70
# 2022-12-02                 0.0     44.605         6.19
# 2022-11-25                 0.0     43.390         5.56
# 2022-11-18                 0.0     51.155        13.69

# %%
# Select a model: use linear regression
model = LinearRegression()

# Split the data into training and test sets
scaler = MinMaxScaler()
X = df[["1. open", "2. high", "3. low", "6. volume", "avg_price", "price_range"]]
X = scaler.fit_transform(X)
y = df["4. close"]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2)

# Train the model on the training data
model.fit(X_train, y_train)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 77.09840290916003

# %%
# Use the trained model to make predictions on new data
#new_data = pd.DataFrame({"avg_price": [100, 150, 200]})
#predictions = model.predict(new_data)
#print("Predictions:", predictions)

new_data = [[100, 110, 90, 90000000, 100,  20], [50, 60, 40, 50000000, 50, 20]]
new_data = scaler.transform(new_data)
predictions = model.predict(new_data)
print(predictions)
# Out:
# [100.92718315  51.28753471]

# %%
# Adjust the hyperparameters: You can use techniques such as grid search 
# or random search to find the optimal hyperparameters for your model.

# %%
# Define the hyperparameter grid
param_grid = {'fit_intercept': [True, False],
              'normalize': [True, False]}

# Initialize the grid search on linear regression using hyperparameters
grid_search = GridSearchCV(model, param_grid, cv=5)

# Fit the grid search to the data
grid_search.fit(X_train, y_train)

# Print the best parameters
print(grid_search.best_params_)
# Out:
# {'fit_intercept': True, 'normalize': True}

# %%
# Retrain model with the best parameters
model = grid_search.best_estimator_
model.fit(X_train, y_train)

# Evaluate the model on the test data
y_pred = modelLin.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)

# Evaluate the model's performance
score = model.score(X_test, y_test)
print(f'Model score: {score:.2f}')
# Out:
# Mean Squared Error: 2.43075401183609e+23
# Model score: 1.00

# %%
model = DecisionTreeRegressor()

# Train the model on the training data
model.fit(X_train, y_train)

# Evaluate the model on the test data
y_pred = model.predict(X_test)
mse = mean_squared_error(y_test, y_pred)
print("Mean Squared Error:", mse)
# Out:
# Mean Squared Error: 404.3689755822282

# %%
# Use the trained model to make predictions on new data
new_data = [[100, 110, 90, 90000000, 100,  20], [50, 60, 40, 50000000, 50, 20]]
new_data = scaler.transform(new_data)
predictions = model.predict(new_data)
print(predictions)
# Out:
# [94.   51.31]
